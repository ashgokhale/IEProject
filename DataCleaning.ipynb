# %%
import pandas as pd

# %%
inj_years = pd.read_csv('ingury_in_years.csv')

# %%
inj_years['Year'] = inj_years['Year'].apply(lambda x: x[:4])

# %%
inj_years
# Out:
#     External cause of injury  Year      Sex  0–4  Total
# 0                  Transport  2008    Males   17   1257
# 1                  Transport  2009    Males   16   1202
# 2                  Transport  2010    Males   21   1197
# 3                  Transport  2011    Males   17   1154
# 4                  Transport  2012    Males    6   1109
# 5                  Transport  2013    Males   16   1055
# 6                  Transport  2014    Males   13   1033
# 7                  Transport  2015    Males   13   1134
# 8                  Transport  2016    Males   15   1059
# 9                  Transport  2017    Males   11   1055
# 10                 Transport  2008  Females   10    446
# 11                 Transport  2009  Females    9    404
# 12                 Transport  2010  Females   15    403
# 13                 Transport  2011  Females   21    416
# 14                 Transport  2012  Females    9    407
# 15                 Transport  2013  Females   10    361
# ...

# %%
inj_world = pd.read_csv('ingury_in_world.csv')
inj_world
# Out:
#          Injury Type  World Deaths  World Rate  Australia Deaths  \
# 0   Traffic injuries         21.99      142661             17.04
# 1           Drowning         19.00      123270             35.31
# 2              Burns         10.89       70638              3.47
# 3        Suffocation         10.25       66483              2.76
# 4              Falls          5.34       34626             14.69
# 5          Poisoning          3.84       24931              1.84
# 6   Assault/Homicide          6.62       42937              4.49
# 7     Other injuries          2.56       16621             25.51
# 8       All injuries         80.50      522167            105.10
# 9           Lower CI         61.02      395823             85.92
# 10          Upper CI         99.99      648630            124.18
#
#     Australia Rate
# 0            31630
# 1            65533
# 2             6440
# 3             5114
# 4            27274
# 5             3409
# 6             8334
# 7            47350
# ...

# %%
inj_world['World Deaths'] = inj_world['World Deaths'].apply(lambda x: round(x))
inj_world['Australia Deaths'] = inj_world['Australia Deaths'].apply(lambda x: round(x))
inj_world
# Out:
#          Injury Type  World Deaths  World Rate  Australia Deaths  \
# 0   Traffic injuries            22      142661                17
# 1           Drowning            19      123270                35
# 2              Burns            11       70638                 3
# 3        Suffocation            10       66483                 3
# 4              Falls             5       34626                15
# 5          Poisoning             4       24931                 2
# 6   Assault/Homicide             7       42937                 4
# 7     Other injuries             3       16621                26
# 8       All injuries            80      522167               105
# 9           Lower CI            61      395823                86
# 10          Upper CI           100      648630               124
#
#     Australia Rate
# 0            31630
# 1            65533
# 2             6440
# 3             5114
# 4            27274
# 5             3409
# 6             8334
# 7            47350
# ...

# %%
inj_years.to_excel('injury_in_years.xlsx')

# %%
inj_world.to_excel('injury_in_world.xlsx')
